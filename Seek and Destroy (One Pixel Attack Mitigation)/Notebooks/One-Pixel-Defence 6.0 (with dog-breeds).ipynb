# %%
import torch
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader, Subset
import random

random.seed(42)


# Define transformations for the dataset
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resizing all images to 128x128
    transforms.ToTensor(),          # Convert images to tensors
])

# Load the dataset
dataset = datasets.ImageFolder(root='animals', transform=transform)
subset_size = int(0.2 * len(dataset))
indices = random.sample(range(len(dataset)), subset_size)
subset = Subset(dataset, indices)



# Display class names
class_names = dataset.classes
print("Class Names:", class_names)

# Create a DataLoader to iterate over the dataset
data_loader = torch.utils.data.DataLoader(subset, batch_size=16, shuffle=True)

# Function to show images in a grid
def show_images(images, labels):
    images = make_grid(images, nrow=4)
    npimg = images.numpy().transpose((1, 2, 0))
    plt.imshow(npimg)
    plt.title([class_names[label] for label in labels])
    plt.show()

# Get a batch of images and labels
images, labels = next(iter(data_loader))

# Show images and labels
show_images(images, labels)

# Print the dimensions of the images
print("Image Dimensions:", images.shape)  # Should be (Batch Size, Channels, Height, Width)
# Out:
# Class Names: ['antelope', 'badger', 'bat', 'bear', 'bee', 'beetle', 'bison', 'boar', 'butterfly', 'cat', 'caterpillar', 'chimpanzee', 'cockroach', 'cow', 'coyote', 'crab', 'crow', 'deer', 'dog', 'dolphin', 'donkey', 'dragonfly', 'duck', 'eagle', 'elephant', 'flamingo', 'fly', 'fox', 'goat', 'goldfish', 'goose', 'gorilla', 'grasshopper', 'hamster', 'hare', 'hedgehog', 'hippopotamus', 'hornbill', 'horse', 'hummingbird', 'hyena', 'jellyfish', 'kangaroo', 'koala', 'ladybugs', 'leopard', 'lion', 'lizard', 'lobster', 'mosquito', 'moth', 'mouse', 'octopus', 'okapi', 'orangutan', 'otter', 'owl', 'ox', 'oyster', 'panda', 'parrot', 'pelecaniformes', 'penguin', 'pig', 'pigeon', 'porcupine', 'possum', 'raccoon', 'rat', 'reindeer', 'rhinoceros', 'sandpiper', 'seahorse', 'seal', 'shark', 'sheep', 'snake', 'sparrow', 'squid', 'squirrel', 'starfish', 'swan', 'tiger', 'turkey', 'turtle', 'whale', 'wolf', 'wombat', 'woodpecker', 'zebra']
# Image Dimensions: torch.Size([16, 3, 128, 128])

# %%
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

# Define a simple CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 32 * 32, 512)
        self.fc2 = nn.Linear(512, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 32 * 32)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize the model, loss function, and optimizer
num_classes = len(class_names)
model = SimpleCNN(num_classes)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
epochs = 10
for epoch in range(epochs):
    running_loss = 0.0
    correct = 0
    total = 0

    # Use TQDM for progress tracking
    for images, labels in tqdm(data_loader, desc=f"Epoch {epoch+1}/{epochs}"):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}, Accuracy: {accuracy:.2f}%")

print("Training Complete!")

torch.save(model.state_dict(), 'classifier_cnn_model.pt')
# Out:
# Epoch 1/10: 100%|██████████| 68/68 [00:16<00:00,  4.23it/s]
# Epoch [1/10], Loss: 4.5779, Accuracy: 1.11%
# Epoch 2/10: 100%|██████████| 68/68 [00:08<00:00,  7.68it/s]
# Epoch [2/10], Loss: 4.3296, Accuracy: 3.98%
# Epoch 3/10: 100%|██████████| 68/68 [00:08<00:00,  7.75it/s]
# Epoch [3/10], Loss: 3.9696, Accuracy: 11.30%
# Epoch 4/10: 100%|██████████| 68/68 [00:08<00:00,  7.77it/s]
# Epoch [4/10], Loss: 3.2435, Accuracy: 24.72%
# Epoch 5/10: 100%|██████████| 68/68 [00:08<00:00,  7.77it/s]
# Epoch [5/10], Loss: 1.7908, Accuracy: 56.02%
# Epoch 6/10: 100%|██████████| 68/68 [00:08<00:00,  7.74it/s]
# Epoch [6/10], Loss: 0.5818, Accuracy: 87.13%
# Epoch 7/10: 100%|██████████| 68/68 [00:08<00:00,  7.91it/s]
# Epoch [7/10], Loss: 0.1374, Accuracy: 96.67%
# Epoch 8/10: 100%|██████████| 68/68 [00:09<00:00,  7.55it/s]
# Epoch [8/10], Loss: 0.0591, Accuracy: 98.52%
# Epoch 9/10: 100%|██████████| 68/68 [00:08<00:00,  7.60it/s]
# Epoch [9/10], Loss: 0.0228, Accuracy: 99.44%
# Epoch 10/10: 100%|██████████| 68/68 [00:09<00:00,  7.51it/s]
# Epoch [10/10], Loss: 0.0064, Accuracy: 99.91%
# Training Complete!

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import random

def test_model(model, data_loader):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=class_names))

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

    indices = random.sample(range(len(dataset)), 3)
    for i in indices:
        image, label = dataset[i]
        image = image.unsqueeze(0).to(device)
        output = model(image)
        _, predicted = torch.max(output.data, 1)
        predicted_label = predicted.item()
        plt.imshow(image.cpu().squeeze().permute(1, 2, 0))
        plt.title(f"Actual: {class_names[label]}, Predicted: {class_names[predicted_label]}")
        plt.show()

test_model(model, data_loader)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#       antelope       1.00      1.00      1.00        12
#         badger       1.00      1.00      1.00        10
#            bat       1.00      1.00      1.00        10
#           bear       1.00      1.00      1.00        13
#            bee       1.00      1.00      1.00         8
#         beetle       1.00      1.00      1.00        11
#          bison       1.00      1.00      1.00        12
#           boar       1.00      1.00      1.00        13
#      butterfly       1.00      1.00      1.00        11
#            cat       1.00      1.00      1.00        19
#    caterpillar       1.00      1.00      1.00        15
#     chimpanzee       1.00      1.00      1.00        10
#      cockroach       1.00      1.00      1.00        13
#            cow       1.00      1.00      1.00        13
#         coyote       1.00      1.00      1.00        12
#           crab       1.00      1.00      1.00        12
#           crow       1.00      1.00      1.00         8
#           deer       1.00      1.00      1.00        12
#            dog       1.00      1.00      1.00         7
#        dolphin       1.00      1.00      1.00         8
#         donkey       1.00      1.00      1.00        14
#      dragonfly       1.00      1.00      1.00        17
#           duck       1.00      1.00      1.00        10
#          eagle       1.00      1.00      1.00         7
#       elephant       1.00      1.00      1.00        10
#       flamingo       1.00      1.00      1.00        10
#            fly       1.00      1.00      1.00        10
#            fox       1.00      1.00      1.00        10
#           goat       1.00      1.00      1.00        10
#       goldfish       1.00      1.00      1.00        15
#          goose       1.00      1.00      1.00        11
#        gorilla       1.00      1.00      1.00        14
#    grasshopper       1.00      1.00      1.00        19
#        hamster       1.00      1.00      1.00        18
#           hare       1.00      1.00      1.00        14
#       hedgehog       1.00      1.00      1.00         8
#   hippopotamus       1.00      1.00      1.00        18
#       hornbill       1.00      1.00      1.00        17
#          horse       1.00      1.00      1.00        13
#    hummingbird       1.00      1.00      1.00        13
#          hyena       1.00      1.00      1.00        17
#      jellyfish       1.00      1.00      1.00        13
#       kangaroo       1.00      1.00      1.00        12
#          koala       1.00      1.00      1.00        10
#       ladybugs       1.00      1.00      1.00        11
#        leopard       1.00      1.00      1.00        16
#           lion       1.00      1.00      1.00        13
#         lizard       1.00      1.00      1.00         9
#        lobster       1.00      1.00      1.00         9
#       mosquito       1.00      1.00      1.00        10
#           moth       1.00      1.00      1.00         7
#          mouse       1.00      1.00      1.00        11
#        octopus       1.00      1.00      1.00        11
#          okapi       1.00      1.00      1.00         5
#      orangutan       1.00      1.00      1.00        16
#          otter       1.00      1.00      1.00        11
#            owl       1.00      1.00      1.00        12
#             ox       1.00      1.00      1.00        13
#         oyster       1.00      1.00      1.00        13
#          panda       1.00      1.00      1.00        13
#         parrot       1.00      1.00      1.00        13
# pelecaniformes       1.00      1.00      1.00        11
#        penguin       1.00      1.00      1.00        16
#            pig       1.00      1.00      1.00        15
#         pigeon       1.00      1.00      1.00        15
#      porcupine       1.00      1.00      1.00         8
#         possum       1.00      1.00      1.00        15
#        raccoon       1.00      1.00      1.00        10
#            rat       1.00      1.00      1.00         9
#       reindeer       1.00      1.00      1.00        12
#     rhinoceros       1.00      1.00      1.00         9
#      sandpiper       1.00      1.00      1.00         6
#       seahorse       1.00      1.00      1.00        11
#           seal       1.00      1.00      1.00        16
#          shark       1.00      1.00      1.00        13
#          sheep       1.00      1.00      1.00        19
#          snake       1.00      1.00      1.00        10
#        sparrow       1.00      1.00      1.00        11
#          squid       1.00      1.00      1.00        11
#       squirrel       1.00      1.00      1.00        15
#       starfish       1.00      1.00      1.00        14
#           swan       1.00      1.00      1.00        13
#          tiger       1.00      1.00      1.00        10
#         turkey       1.00      1.00      1.00         9
#         turtle       1.00      1.00      1.00        12
#          whale       1.00      1.00      1.00        13
#           wolf       1.00      1.00      1.00        12
#         wombat       1.00      1.00      1.00         9
#     woodpecker       1.00      1.00      1.00        12
#          zebra       1.00      1.00      1.00        12
#
#       accuracy                           1.00      1080
#      macro avg       1.00      1.00      1.00      1080
#   weighted avg       1.00      1.00      1.00      1080

# %%
'''import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import differential_evolution
from tqdm import tqdm

def one_pixel_attack(image, label, model, bounds, maxiter=20):
    def perturb_pixel(pixel):
        perturbed_image = image.clone()
        perturbed_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)
        with torch.no_grad():
            output = model(perturbed_image)
        loss = -F.cross_entropy(output, torch.tensor([label], device=image.device))
        return loss.item()
    
    result = differential_evolution(perturb_pixel, bounds=bounds, maxiter=maxiter, popsize=10)
    return result.x

bounds = [(0, 127), (0, 127), (0, 1), (0, 1), (0, 1)]  

model.eval()

dog_breeds_attacked = []
patch_data = []

batch_size = 32
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)

for batch_idx, (images, labels) in tqdm(enumerate(dataloader), total=len(dataloader), desc="Attacking images"):
    images = images.to(device)
    labels = labels.to(device)
    
    for i in range(images.size(0)):
        image = images[i].unsqueeze(0)
        label = labels[i]
        
        pixel = one_pixel_attack(image, label, model, bounds)
        attacked_image = image.clone()
        attacked_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)
        
        dog_breeds_attacked.append((attacked_image.cpu().squeeze(), label.item()))
        
        patch_size = 16
        for row in range(0, 128, patch_size):
            for col in range(0, 128, patch_size):
                patch = attacked_image[:, :, row:row+patch_size, col:col+patch_size]
                patch_id = f"[{batch_idx * batch_size + i}][{row//patch_size * 8 + col//patch_size}]"
                attacked_or_not = 1 if (row <= pixel[0] < row + patch_size and col <= pixel[1] < col + patch_size) else 0
                patch_data.append((patch.cpu().squeeze(), patch_id, attacked_or_not))

    if (batch_idx + 1) % 10 == 0:
        torch.save(dog_breeds_attacked, f'animals-attacked-{batch_idx+1}.pt')
        torch.save(patch_data, f'Patch-data-{batch_idx+1}.pt')
        dog_breeds_attacked = []
        patch_data = []

# Save any remaining data
if dog_breeds_attacked:
    torch.save(dog_breeds_attacked, f'animals-attacked.pt')
if patch_data:
    torch.save(patch_data, f'Patch-data.pt')'''
# Out:
# 'import torch\nimport torch.nn.functional as F\nimport numpy as np\nfrom scipy.optimize import differential_evolution\nfrom tqdm import tqdm\n\ndef one_pixel_attack(image, label, model, bounds, maxiter=20):\n    def perturb_pixel(pixel):\n        perturbed_image = image.clone()\n        perturbed_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)\n        with torch.no_grad():\n            output = model(perturbed_image)\n        loss = -F.cross_entropy(output, torch.tensor([label], device=image.device))\n        return loss.item()\n    \n    result = differential_evolution(perturb_pixel, bounds=bounds, maxiter=maxiter, popsize=10)\n    return result.x\n\nbounds = [(0, 127), (0, 127), (0, 1), (0, 1), (0, 1)]  \n\nmodel.eval()\n\ndog_breeds_attacked = []\npatch_data = []\n\nbatch_size = 32\ndataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)\n\nfor batch_idx, (images, labels) in tqdm(enumerate(dataloader), total=len(dataloader), desc="Attacking images"):\n    images = images.to(device)\n    labels = labels.to(device)\n    \n    for i in range(images.size(0)):\n        image = images[i].unsqueeze(0)\n        label = labels[i]\n        \n        pixel = one_pixel_attack(image, label, model, bounds)\n        attacked_image = image.clone()\n        attacked_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)\n        \n        dog_breeds_attacked.append((attacked_image.cpu().squeeze(), label.item()))\n        \n        patch_size = 16\n        for row in range(0, 128, patch_size):\n            for col in range(0, 128, patch_size):\n                patch = attacked_image[:, :, row:row+patch_size, col:col+patch_size]\n                patch_id = f"[{batch_idx * batch_size + i}][{row//patch_size * 8 + col//patch_size}]"\n                attacked_or_not = 1 if (row <= pixel[0] < row + patch_size and col <= pixel[1] < col + patch_size) else 0\n                patch_data.append((patch.cpu().squeeze(), patch_id, attacked_or_not))\n\n    if (batch_idx + 1) % 10 == 0:\n        torch.save(dog_breeds_attacked, f\'animals-attacked-{batch_idx+1}.pt\')\n        torch.save(patch_data, f\'Patch-data-{batch_idx+1}.pt\')\n        dog_breeds_attacked = []\n        patch_data = []\n\n# Save any remaining data\nif dog_breeds_attacked:\n    torch.save(dog_breeds_attacked, f\'animals-attacked.pt\')\nif patch_data:\n    torch.save(patch_data, f\'Patch-data.pt\')'

# %%
import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import differential_evolution
from tqdm import tqdm

def one_pixel_attack(image, label, model, bounds, maxiter=20):
    def perturb_pixel(pixel):
        perturbed_image = image.clone()
        perturbed_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)
        with torch.no_grad():
            output = model(perturbed_image)
        loss = -F.cross_entropy(output, torch.tensor([label], device=image.device))
        return loss.item()
    
    result = differential_evolution(perturb_pixel, bounds=bounds, maxiter=maxiter, popsize=10)
    return result.x

bounds = [(0, 127), (0, 127), (0, 1), (0, 1), (0, 1)]  

model.eval()

dog_breeds_attacked = []
patch_data = []

batch_size = 32
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)

for batch_idx, (images, labels) in tqdm(enumerate(dataloader), total=len(dataloader), desc="Attacking images"):
    images = images.to(device)
    labels = labels.to(device)
    
    for i in range(images.size(0)):
        image = images[i].unsqueeze(0)
        label = labels[i]
        
        pixel = one_pixel_attack(image, label, model, bounds)
        attacked_image = image.clone()
        attacked_image[0, :, int(pixel[0]), int(pixel[1])] = torch.tensor(pixel[2:], device=image.device)
        
        dog_breeds_attacked.append((attacked_image.cpu().squeeze(), label.item()))
        
        patch_size = 16
        for row in range(0, 128, patch_size):
            for col in range(0, 128, patch_size):
                patch = attacked_image[:, :, row:row+patch_size, col:col+patch_size]
                patch_id = f"[{batch_idx * batch_size + i}][{row//patch_size * 8 + col//patch_size}]"
                attacked_or_not = 1 if (row <= pixel[0] < row + patch_size and col <= pixel[1] < col + patch_size) else 0
                patch_data.append((patch.cpu().squeeze(), patch_id, attacked_or_not))

# Save the complete datasets
torch.save(dog_breeds_attacked, 'animals-attacked.pt')
torch.save(patch_data, 'Patch-data.pt')
# Out:
# Attacking images: 100%|██████████| 169/169 [56:18<00:00, 19.99s/it]

# %%
import torch

# Load the datasets
dog_breeds_attacked = torch.load('animals-attacked.pt')
patch_data = torch.load('Patch-data.pt')
dataset = datasets.ImageFolder(root='dog-breeds', transform=transform)

# Get the number of samples
num_attacked_samples = len(dog_breeds_attacked)
num_patch_samples = len(patch_data)
num_originl_samples = len(dataset)

print(f'Total number of samples in animals-attacked.pt: {num_attacked_samples}')
print(f'Total number of samples in Patch-data.pt: {num_patch_samples}')
print(f'Total number of samples in original dataset: {num_originl_samples}')
# Out:
# Total number of samples in animals-attacked.pt: 5400
# Total number of samples in Patch-data.pt: 345600
# Total number of samples in original dataset: 967

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

dog_breeds_attacked = torch.load('animals-attacked.pt')

model.eval()

all_preds = []
all_labels = []
loss_fn = torch.nn.CrossEntropyLoss()

with torch.no_grad():
    for attacked_image, label in tqdm(dog_breeds_attacked, desc="Testing attacked dataset"):
        attacked_image = attacked_image.unsqueeze(0).to(device)  # Add batch dimension
        label = torch.tensor(label).to(device)  # Convert label to tensor
        
        output = model(attacked_image)
        loss = loss_fn(output, label.unsqueeze(0))  # Compute loss
        
        _, predicted = torch.max(output, 1)  # Get predicted class
        
        all_preds.append(predicted.item())
        all_labels.append(label.item())

# Calculate accuracy
accuracy = np.sum(np.array(all_preds) == np.array(all_labels)) / len(all_labels)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Display classification report
print("Classification Report:")
print(classification_report(all_labels, all_preds))

# Plot confusion matrix
conf_matrix = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(all_labels), yticklabels=np.unique(all_labels))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# Show actual and predicted classes for 3 random images
random_indices = np.random.choice(len(dog_breeds_attacked), size=3, replace=False)

plt.figure(figsize=(12, 4))
for i, idx in enumerate(random_indices):
    attacked_image, label = dog_breeds_attacked[idx]
    attacked_image = attacked_image.permute(1, 2, 0)  # Rearrange for plotting
    attacked_image = attacked_image.numpy()

    # Get prediction
    predicted = all_preds[idx]
    
    plt.subplot(1, 3, i + 1)
    plt.imshow(attacked_image)
    plt.title(f'Actual: {label}, Predicted: {predicted}')
    plt.axis('off')

plt.show()
# Out:
# Testing attacked dataset: 100%|██████████| 5400/5400 [00:09<00:00, 568.36it/s]
# Accuracy: 29.13%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.30      0.27        60
#            1       0.26      0.17      0.20        60
#            2       0.34      0.20      0.25        60
#            3       0.18      0.37      0.25        60
#            4       0.52      0.20      0.29        60
#            5       0.32      0.23      0.27        60
#            6       0.19      0.33      0.24        60
#            7       0.19      0.30      0.23        60
#            8       1.00      0.17      0.29        60
#            9       0.26      0.40      0.31        60
#           10       0.13      0.43      0.20        60
#           11       0.63      0.20      0.30        60
#           12       0.38      0.40      0.39        60
#           13       0.30      0.25      0.27        60
#           14       0.40      0.35      0.37        60
#           15       0.76      0.32      0.45        60
#           16       0.34      0.30      0.32        60
#           17       0.21      0.38      0.28        60
#           18       0.56      0.17      0.26        60
#           19       0.68      0.25      0.37        60
#           20       0.33      0.28      0.30        60
#           21       0.39      0.37      0.38        60
#           22       0.26      0.22      0.24        60
#           23       0.60      0.20      0.30        60
#           24       0.73      0.18      0.29        60
#           25       0.74      0.28      0.41        60
#           26       0.37      0.27      0.31        60
#           27       0.34      0.23      0.28        60
#           28       0.26      0.20      0.22        60
#           29       0.92      0.20      0.33        60
#           30       0.29      0.23      0.26        60
#           31       0.47      0.45      0.46        60
#           32       0.16      0.43      0.23        60
#           33       0.48      0.37      0.42        60
#           34       0.15      0.38      0.22        60
#           35       0.41      0.22      0.28        60
#           36       0.18      0.40      0.24        60
#           37       0.34      0.40      0.37        60
#           38       0.37      0.28      0.32        60
#           39       0.59      0.33      0.43        60
#           40       0.25      0.43      0.32        60
#           41       0.57      0.27      0.36        60
#           42       0.83      0.25      0.38        60
#           43       0.27      0.25      0.26        60
#           44       0.08      0.48      0.14        60
#           45       0.08      0.42      0.14        60
#           46       0.19      0.25      0.22        60
#           47       0.31      0.22      0.25        60
#           48       0.59      0.22      0.32        60
#           49       0.49      0.37      0.42        60
#           50       0.40      0.13      0.20        60
#           51       0.16      0.35      0.22        60
#           52       0.28      0.22      0.24        60
#           53       0.70      0.12      0.20        60
#           54       0.16      0.53      0.24        60
#           55       0.70      0.23      0.35        60
#           56       0.35      0.25      0.29        60
#           57       0.70      0.32      0.44        60
#           58       0.44      0.32      0.37        60
#           59       0.43      0.32      0.37        60
#           60       0.39      0.27      0.32        60
#           61       0.85      0.28      0.42        60
#           62       0.38      0.35      0.37        60
#           63       0.36      0.33      0.34        60
#           64       0.33      0.33      0.33        60
#           65       0.42      0.18      0.26        60
#           66       0.55      0.35      0.43        60
#           67       0.40      0.20      0.27        60
#           68       0.33      0.18      0.24        60
#           69       0.79      0.25      0.38        60
#           70       0.60      0.20      0.30        60
#           71       1.00      0.12      0.21        60
#           72       0.28      0.30      0.29        60
#           73       0.34      0.42      0.38        60
#           74       0.60      0.20      0.30        60
#           75       0.69      0.40      0.51        60
#           76       0.81      0.22      0.34        60
#           77       0.61      0.28      0.39        60
#           78       0.41      0.27      0.32        60
#           79       0.30      0.35      0.33        60
#           80       0.16      0.40      0.23        60
#           81       0.61      0.23      0.34        60
#           82       0.50      0.23      0.32        60
#           83       0.62      0.17      0.26        60
#           84       0.53      0.28      0.37        60
#           85       0.22      0.72      0.33        60
#           86       0.53      0.32      0.40        60
#           87       0.50      0.23      0.32        60
#           88       0.27      0.33      0.30        60
#           89       0.52      0.23      0.32        60
#
#     accuracy                           0.29      5400
#    macro avg       0.44      0.29      0.31      5400
# weighted avg       0.44      0.29      0.31      5400

# %%
import torch
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

dog_breeds_attacked = torch.load('animals-attacked.pt')

def show_image(image_tensor, title=""):
    image = image_tensor.squeeze(0)  # Remove the batch dimension
    image = transforms.ToPILImage()(image)  # Convert tensor to PIL image
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Preview a few images from the attacked dataset
for i in range(3):  # Change the range to see more examples
    attacked_image, label = dog_breeds_attacked[i]
    print(f"Class Label: {label}")
    show_image(attacked_image, title=f"Attacked Image {i+1} - Class {label}")
attacked_image.shape
# Out:
# Class Label: 0
# Class Label: 0
# Class Label: 0
# torch.Size([3, 128, 128])

# %%
import torch
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# Load the patch dataset
patch_data = torch.load('Patch-data.pt')

# Function to display a patch
def show_patch(patch_tensor, patch_id, attacked_or_not):
    patch = patch_tensor.squeeze(0)  # Remove the batch dimension
    patch = transforms.ToPILImage()(patch)  # Convert tensor to PIL image
    plt.imshow(patch)
    title = f"Patch ID: {patch_id}, Attacked: {attacked_or_not}"
    plt.title(title)
    plt.axis('off')
    plt.show()

# Preview a few patches from the patch dataset
for i in range(3):  # Change the range to see more examples
    patch_tensor, patch_id, attacked_or_not = patch_data[i]
    show_patch(patch_tensor, patch_id, attacked_or_not)
patch_tensor, _, _ = patch_data[0]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import torch.nn.functional as F


# Define the CNN model
class PatchCNN(nn.Module):
    def __init__(self):
        super(PatchCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 4 * 4, 128)  # Assuming 16x16 input patches
        self.fc2 = nn.Linear(128, 2)  # Binary classification

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)  # Flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # No activation here; use softmax in the loss function
        return x

class PatchDataset(Dataset):
    def __init__(self, patch_data):
        self.patches = patch_data

    def __len__(self):
        return len(self.patches)

    def __getitem__(self, idx):
        patch, patch_id, attacked_or_not = self.patches[idx]
        return patch.float(), attacked_or_not  # Return the patch and label

# Load the patch data
patch_data = torch.load('Patch-data.pt')
dataset = PatchDataset(patch_data)
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# Initialize the model, loss function, and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = PatchCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training parameters
num_epochs = 10

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    with tqdm(total=len(data_loader), desc=f'Epoch {epoch + 1}/{num_epochs}') as pbar:
        for patches, labels in data_loader:
            patches, labels = patches.to(device), labels.to(device)

            # Forward pass
            outputs = model(patches)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Calculate running loss and accuracy
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            pbar.set_postfix(loss=running_loss / (pbar.n + 1), accuracy=correct / total)
            pbar.update(1)

    # Print average loss and accuracy for the epoch
    avg_loss = running_loss / len(data_loader)
    accuracy = correct / total
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/10: 100%|██████████| 10800/10800 [00:47<00:00, 228.50it/s, accuracy=0.994, loss=0.0277]
# Epoch [1/10], Loss: 0.0277, Accuracy: 99.41%
# Epoch 2/10: 100%|██████████| 10800/10800 [00:55<00:00, 193.04it/s, accuracy=0.998, loss=0.00795]
# Epoch [2/10], Loss: 0.0079, Accuracy: 99.83%
# Epoch 3/10: 100%|██████████| 10800/10800 [00:58<00:00, 185.03it/s, accuracy=0.999, loss=0.0055]
# Epoch [3/10], Loss: 0.0055, Accuracy: 99.89%
# Epoch 4/10: 100%|██████████| 10800/10800 [00:58<00:00, 186.08it/s, accuracy=0.999, loss=0.00409]
# Epoch [4/10], Loss: 0.0041, Accuracy: 99.91%
# Epoch 5/10: 100%|██████████| 10800/10800 [00:58<00:00, 184.02it/s, accuracy=0.999, loss=0.00401]
# Epoch [5/10], Loss: 0.0040, Accuracy: 99.92%
# Epoch 6/10: 100%|██████████| 10800/10800 [00:59<00:00, 183.01it/s, accuracy=0.999, loss=0.00318]
# Epoch [6/10], Loss: 0.0032, Accuracy: 99.93%
# Epoch 7/10: 100%|██████████| 10800/10800 [00:59<00:00, 181.74it/s, accuracy=0.999, loss=0.00281]
# Epoch [7/10], Loss: 0.0028, Accuracy: 99.94%
# Epoch 8/10: 100%|██████████| 10800/10800 [00:58<00:00, 183.27it/s, accuracy=0.999, loss=0.00306]
# Epoch [8/10], Loss: 0.0031, Accuracy: 99.93%
# Epoch 9/10: 100%|██████████| 10800/10800 [00:48<00:00, 222.28it/s, accuracy=0.999, loss=0.00287]
# Epoch [9/10], Loss: 0.0029, Accuracy: 99.94%
# Epoch 10/10: 100%|██████████| 10800/10800 [01:01<00:00, 176.44it/s, accuracy=0.999, loss=0.00335]
# Epoch [10/10], Loss: 0.0033, Accuracy: 99.94%

# %%
torch.save(model.state_dict(), 'patchCNN.pt')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

dog_breeds_attacked = torch.load('animals-attacked.pt')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


model = PatchCNN().to(device)
model.load_state_dict(torch.load('patchCNN.pt'))  

def calculate_difference_map(patch):
    difference_map = torch.zeros(patch.shape[2:]).to(device)
    for i in range(1, patch.shape[2] - 1):
        for j in range(1, patch.shape[3] - 1):
            center_pixel = patch[:, :, i, j]
            neighbors = torch.stack([
                patch[:, :, i-1, j], patch[:, :, i+1, j],
                patch[:, :, i, j-1], patch[:, :, i, j+1]
            ])
            difference_map[i, j] = torch.sum(torch.abs(center_pixel - torch.mean(neighbors, dim=0)))
    return difference_map

# Function to create the average map
def create_average_map(patch):
    avg_map = torch.zeros_like(patch).to(device)
    for i in range(1, patch.shape[2] - 1):
        for j in range(1, patch.shape[3] - 1):
            neighbors = torch.stack([
                patch[:, :, i-1, j], patch[:, :, i+1, j],
                patch[:, :, i, j-1], patch[:, :, i, j+1]
            ])
            avg_pixel = torch.mean(neighbors, dim=0)  
            avg_map[:, :, i, j] = avg_pixel  
    return avg_map

# Repair mechanism
def repair_image(image):
    patch_size = 16
    patches = []
    patch_probs = []

    for row in range(0, 128, patch_size):
        for col in range(0, 128, patch_size):
            patch = image[:, :, row:row + patch_size, col:col + patch_size]
            patches.append(patch)

    with torch.no_grad():
        for patch in tqdm(patches, desc="Processing patches"):
            patch = patch.to(device)
            output = model(patch)
            prob = F.softmax(output, dim=1)
            patch_probs.append(prob[0][1].item()) 

    attacked_patch_index = patch_probs.index(max(patch_probs))

    attacked_patch = patches[attacked_patch_index]
    difference_map = calculate_difference_map(attacked_patch)
    average_map = create_average_map(attacked_patch)

    max_diff_idx = torch.argmax(difference_map)
    max_diff_pos = torch.unravel_index(max_diff_idx, difference_map.shape)

    row = (attacked_patch_index // 8) * patch_size
    col = (attacked_patch_index % 8) * patch_size
    image[:, :, row + max_diff_pos[0], col + max_diff_pos[1]] = average_map[:, :, max_diff_pos[0], max_diff_pos[1]]

    return image

repaired_images = []

for attacked_image, label in tqdm(dog_breeds_attacked, desc="Repairing images"):
    attacked_image = attacked_image.unsqueeze(0).to(device)  # Add batch dimension
    repaired_image = repair_image(attacked_image)
    repaired_images.append((repaired_image.cpu(), label))

torch.save(repaired_images, 'repaired_images.pt')
# Out:
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1453.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1866.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1578.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1537.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1759.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1748.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1802.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1661.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1732.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1661.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1448.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1416.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1456.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1194.99it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1026.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 581.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1579.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1654.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1573.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1702.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1670.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1783.19it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1771.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1581.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1477.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1612.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1326.72it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1271.49it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1599.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1688.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1673.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1769.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1482.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1367.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1438.02it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1383.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1407.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1401.73it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1518.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 466.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1687.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1493.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1682.46it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1541.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1513.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1155.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1541.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1368.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1667.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1612.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1618.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1459.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1295.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1610.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1464.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1529.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1042.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 766.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 738.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1314.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1353.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1264.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1352.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1339.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1444.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1491.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1495.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1162.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1257.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1340.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1451.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1454.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1382.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1330.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 577.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1194.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1540.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1461.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1401.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1637.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1545.19it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1342.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1329.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1342.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1611.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1444.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1491.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1247.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1596.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 845.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 962.08it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1062.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 658.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1604.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1552.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1535.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1352.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1286.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1442.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1500.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1368.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1483.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1446.05it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.28it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1425.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1541.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1492.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1543.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1473.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 600.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1591.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1397.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1260.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1620.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1518.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1479.05it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1606.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1641.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1420.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1520.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1538.72it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1564.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1478.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1562.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1454.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 651.93it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1366.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1481.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1439.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1447.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1520.85it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1421.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1499.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1450.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1511.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1361.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1650.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1401.28it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1514.99it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 723.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1225.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1581.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1361.02it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1580.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1379.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1502.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1266.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1601.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1632.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1436.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1586.46it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1579.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1368.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1540.08it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1408.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1577.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 826.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 844.88it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 819.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 880.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 844.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 749.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 909.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 858.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 912.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 909.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 866.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 888.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 865.80it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 828.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 868.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 818.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 789.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 952.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 600.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 749.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 934.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 786.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1246.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1399.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1333.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1334.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1251.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1366.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1247.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1381.80it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1077.88it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1514.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1534.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1348.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1509.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 866.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 810.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1460.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1357.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1474.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1475.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1372.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1286.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1473.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1141.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1320.88it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1451.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1352.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1489.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1035.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1505.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 622.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1674.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1518.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1737.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1569.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1554.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1378.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1328.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1759.93it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1521.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1643.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1552.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1672.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1528.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1705.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1349.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 840.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 985.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 872.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 646.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1387.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1575.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1568.46it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1512.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1461.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1486.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1580.72it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1373.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1427.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1423.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1470.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1557.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1461.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1349.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1608.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1247.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 872.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 915.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 758.02it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1016.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1342.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1625.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1659.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1632.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1356.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1472.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1399.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1455.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1514.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1540.93it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1232.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1240.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1297.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 733.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 784.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 595.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 674.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 862.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 841.15it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 760.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 975.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1195.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1476.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1336.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1404.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1498.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1467.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1488.93it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1479.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1606.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1701.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1454.49it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1427.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1234.02it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 892.85it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1471.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1468.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1507.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1640.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1594.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1691.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1676.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1516.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1516.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1682.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1606.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1754.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1725.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1603.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1616.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1680.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1745.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1576.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1489.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1386.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1495.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1670.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1544.46it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1708.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1639.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1660.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1426.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1485.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1458.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1693.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.72it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1331.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1409.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1279.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1493.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1625.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1693.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1663.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1636.63it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1260.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1094.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1216.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1578.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 669.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1563.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1654.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1552.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1436.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1494.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1232.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1481.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1501.97it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.15it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1500.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1465.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1424.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1585.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1425.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1569.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1469.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 667.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1455.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1525.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1431.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1440.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1325.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1477.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1688.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1669.19it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1676.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1481.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1214.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1443.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1241.08it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1354.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1468.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 500.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1633.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1546.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1610.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1560.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1289.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1414.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1433.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1478.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1495.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1493.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1354.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1448.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1440.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1448.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1446.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 627.15it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 972.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1589.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1456.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1658.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1356.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1212.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1522.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1504.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1405.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1504.73it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1592.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1602.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1552.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1423.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 647.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1466.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1543.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1395.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1127.88it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1630.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1400.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1389.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1345.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1302.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1401.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1427.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1491.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1441.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1499.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1470.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1206.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 764.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 671.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1542.63it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1396.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1407.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1487.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1312.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1405.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1586.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1494.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1546.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1484.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1577.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1391.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1666.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1573.63it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1439.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 853.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 542.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1572.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1657.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1541.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1123.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1283.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1594.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1633.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1231.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1437.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1403.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1550.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1449.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1484.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1501.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1458.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 525.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 779.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1242.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1567.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1526.99it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1329.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1325.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1520.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1386.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1427.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1458.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1453.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1489.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1415.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1671.48it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1512.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1646.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 599.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1548.81it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1692.48it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1463.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1507.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1496.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1448.49it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1371.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1438.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1266.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1463.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1600.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.67it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1682.15it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1687.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1546.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1298.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 810.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 817.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 767.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 839.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 852.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 837.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 890.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 569.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 875.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 759.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 892.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1024.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1149.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1463.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1469.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1362.08it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1257.20it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1470.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1542.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1502.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1347.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1499.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1497.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1322.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1503.41it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1589.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 666.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1556.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1304.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1390.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1312.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1055.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1405.99it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1529.60it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1421.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1410.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1448.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1471.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1482.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1134.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1358.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1424.73it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 678.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1553.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1571.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1478.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1192.24it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1546.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1359.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1416.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1376.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1372.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1572.49it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1484.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1341.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1500.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1371.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1614.80it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1215.93it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 898.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 955.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 654.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 648.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1508.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1410.63it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1536.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1482.73it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1578.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1600.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1556.85it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1296.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1306.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1314.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1508.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1447.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1473.28it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1604.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1449.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1423.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 690.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1514.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1502.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1369.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1534.97it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1514.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1378.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1317.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1335.67it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1376.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1351.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1544.36it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1525.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1582.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1555.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1273.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 727.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 972.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1402.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1456.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1512.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1288.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1540.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1497.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1260.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1366.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1504.89it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1464.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1419.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1455.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1465.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1411.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1496.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 658.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1736.55it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1576.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1446.14it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1313.73it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1406.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1598.67it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1549.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1296.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1377.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1356.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1332.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1250.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1529.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1505.02it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1420.06it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 904.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 766.97it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 868.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1519.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1613.84it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1481.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1358.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1484.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1334.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1462.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1547.98it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1479.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1492.48it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1315.63it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1495.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1394.30it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1386.68it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1483.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 552.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1591.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1492.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1567.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1484.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1561.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1437.10it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1379.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1316.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1428.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1438.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1542.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1261.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1577.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1446.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1532.67it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 907.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 664.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 984.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 968.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 955.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 866.28it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 561.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1622.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1584.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1417.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1340.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1562.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1525.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1361.46it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1394.83it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1385.80it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1550.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1509.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1509.34it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1547.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1574.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 902.07it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 645.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 588.43it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1356.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1562.08it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1363.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1562.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1441.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1604.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1706.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1480.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1481.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1601.64it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1396.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1592.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1485.42it/s]
# ...
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1441.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1555.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1638.42it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1483.94it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1474.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 749.34it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 786.06it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 797.36it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 832.74it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 782.26it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 773.17it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1170.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1066.91it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1065.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1037.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1263.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1358.79it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1436.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1506.05it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1345.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1480.27it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1680.44it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1400.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1614.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1637.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1674.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1506.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1399.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1667.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1596.11it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1733.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1472.53it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1612.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1733.72it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1518.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1642.92it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1537.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1676.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1725.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1625.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1523.82it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1656.50it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1346.09it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1684.04it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1520.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1583.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1519.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1471.96it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1472.97it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1636.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 769.52it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 764.72it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 914.72it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 779.73it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 833.47it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 842.35it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 770.50it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 813.60it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 855.55it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 701.95it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 698.97it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 820.72it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 740.65it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 762.28it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 869.31it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 656.84it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 869.55it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 803.29it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 801.45it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 800.36it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 777.97it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 802.28it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 793.96it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 857.14it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 842.15it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 751.72it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 819.92it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 758.59it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 840.30it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 828.09it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 711.14it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 830.11it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 868.97it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 752.86it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 854.25it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 543.16it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 807.76it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 669.90it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 792.31it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 662.47it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 798.98it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 750.11it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 533.14it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 689.66it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 775.46it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 766.69it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 700.35it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 791.45it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 800.41it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 768.11it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 810.36it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 804.08it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 801.93it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 741.41it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 824.44it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 698.02it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 681.62it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 871.60it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 680.23it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 946.45it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1179.38it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 942.36it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1105.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 981.95it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1396.49it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1397.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1332.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1281.17it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1351.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1469.70it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1361.26it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1403.58it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1237.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 655.31it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 852.01it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 809.35it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 822.74it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 666.31it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 802.80it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 743.69it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 847.15it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 806.50it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 923.83it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 868.11it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 866.64it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 773.56it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 852.64it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 921.17it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 836.69it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 759.30it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 947.67it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1142.95it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 962.61it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1054.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1126.22it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.40it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1711.86it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1442.19it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1533.97it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1565.35it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1366.52it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1310.18it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1770.29it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1473.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1944.75it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1899.19it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1780.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1780.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1700.76it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1791.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1772.16it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1425.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1566.88it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1880.23it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1552.71it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1659.03it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1593.05it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1636.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1609.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1869.31it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1343.56it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1623.80it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1954.90it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1691.85it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 807.69it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 821.12it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 885.81it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 674.35it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 874.95it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 668.38it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1069.61it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1034.45it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1069.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 929.81it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 924.86it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1195.00it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1490.12it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1309.33it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1385.39it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1220.51it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1608.62it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1590.77it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1723.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1477.32it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1402.37it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 756.76it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 849.12it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 793.87it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 826.65it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 691.53it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 754.69it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 798.02it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 796.39it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 766.83it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 736.95it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 768.04it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 670.38it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 728.52it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 984.01it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1159.57it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 882.56it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1067.66it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 950.99it/s]]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1461.21it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1607.65it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1205.59it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1334.74it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1605.87it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1695.01it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1376.13it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1759.54it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1416.25it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1556.69it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1749.78it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1587.47it/s]
# Processing patches: 100%|██████████| 64/64 [00:00<00:00, 1775.07it/s]
# Repairing images: 100%|██████████| 5400/5400 [11:56<00:00,  7.53it/s]

# %%
import torch
import matplotlib.pyplot as plt
import random

# Load the repaired images
repaired_images = torch.load('repaired_images.pt')

# Number of images to display
num_images_to_display = 5

# Randomly select images and labels
random_indices = random.sample(range(len(repaired_images)), num_images_to_display)

# Set up the plot
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))

for ax, idx in zip(axes, random_indices):
    repaired_image, label = repaired_images[idx]
    
    # Remove the batch dimension
    repaired_image = repaired_image.squeeze(0)  # Shape from [1, C, H, W] to [C, H, W]
    repaired_image = repaired_image.permute(1, 2, 0)  # Change shape from [C, H, W] to [H, W, C]
    
    # Display the image and its label
    ax.imshow(repaired_image.cpu().numpy())
    ax.set_title(f'Label: {label}')
    ax.axis('off')  # Hide axes ticks

plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Load the repaired images
repaired_images = torch.load('repaired_images.pt')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
classifier_model = SimpleCNN(num_classes).to(device)
classifier_model.load_state_dict(torch.load('classifier_cnn_model.pt'))
classifier_model.eval()

# Evaluate on repaired images
true_labels = []
predicted_labels = []

with torch.no_grad():
    for repaired_image, label in repaired_images:
        repaired_image = repaired_image.squeeze(0).to(device)  # Remove any unnecessary dimensions
        output = classifier_model(repaired_image)
        _, predicted = torch.max(output, 1)
        true_labels.append(label)  # Append label directly
        predicted_labels.append(predicted.item())

# Generate classification report and confusion matrix
print("Classification Report:")
print(classification_report(true_labels, predicted_labels))

# Calculate accuracy
accuracy = sum(np.array(true_labels) == np.array(predicted_labels)) / len(true_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Plot confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       9 repaired_images = torch.load('repaired_images.pt')
#      11 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ---> 12 classifier_model = SimpleCNN(num_classes).to(device)
#      13 classifier_model.load_state_dict(torch.load('classifier_cnn_model.pt'))
#      14 classifier_model.eval()
#
# NameError: name 'SimpleCNN' is not defined
